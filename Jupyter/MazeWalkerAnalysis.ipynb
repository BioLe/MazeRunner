# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfMazeWalker = pd.read_csv('MazeWalker_2018-10-30_14-00-59.csv')
dfMazeWalker
# Out:
#           Epoch  ElapsedTime  BestGene0_CurEpoch  BestGene1_CurEpoch  \
# 0      5.003251            1                 223                  49
# 1     10.012870            2                 354                  46
# 2     15.015480            3                 354                 218
# 3     20.018620            4                 354                 218
# 4     25.024520            5                 354                 218
# 5     30.028750            6                 354                 218
# 6     35.031930            7                 354                 218
# 7     40.035090            8                 354                 218
# 8     45.041130            9                 354                 218
# 9     50.044070           10                 354                 218
# 10    55.047570           11                 354                 218
# 11    60.050400           12                 354                 218
# 12    65.053710           13                 354                 218
# ...

# %%
dfMazeWalker.plot(x='Epoch', y=dfMazeWalker.columns[1:], figsize=(20,10))

# %%
#ElapsedTime é a epoch
#Epoch é o time elapsed 
#so neste ficheiro
dfMazeWalker.plot(x='ElapsedTime', y=['AvgDistanceTravelled', 'MaxDistanceTravelled'], figsize=(20,10), grid=True, title='Distance information')

# %%
dfMazeWalker.plot(x='ElapsedTime', y=['BestGene0_CurEpoch', 'BestGene1_CurEpoch'], figsize=(20,10), grid=True, title='Gene evolution')

# %%
dfMazeWalker.plot(x='ElapsedTime', y=['BestBotGene0_Run', 'BestBotGene1_Run'], figsize=(20,10), grid=True, title='Best Gene this run')

# %%
dfMazeWalker.plot(x='ElapsedTime', y=['BestMaxDistance_Run'], figsize=(20,10), grid=True, title='Best Gene')

# %%
dfMazeWalker.plot(x='ElapsedTime', y=['GenerationOfBestBot'], figsize=(20,10), grid=True, title='Best Gene')
